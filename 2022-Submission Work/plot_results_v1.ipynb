# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

# %%
# datapoints=[100,200,300,400,500,600,700,800,1000,2000,3000,4000,5000]
# Gas_mean = [29654,80656,108084,136223,164402,192607,220863,249146,277481,305854,591689,881430,1000000]
# Gas_variance=[89761,116422,160750,205789,250868,295973,341129,386312,431547,476820,931655,1000000,1000000]

datapoints=[100,200,300,400,500,600,700,800,900,1000,\
            1100,1200,1300,1400,1500,1600,1700,1800,1900,2000,\
           2100,2200,2300,2400,2500,2600,2700,2800,2900,3000]
Gas_mean = [29654,80656,108084,136223,164402,192607,220863,249146,277481,305854,\
            334255,362706,391185,419715,448283,476879,505526,534200,562925,591689,\
           620480,649322,678204,707112,736071,765058,794095,823172,852275,881430]

Gas_variance=[89761,116422,160750,205789,250868,295973,341129,386312,431547,476820,\
              522121,567472,612851,658281,703749,749245,794932,840366,885991,931655,\
             977346,1023088,1068870,1114678,1160537,1206424,1252361,1298338,1344341,1390396]


# bx = plt.subplots()
fig = plt.figure(figsize=(10, 10))
plt.plot(datapoints,Gas_mean, color='b',label ='Mean | y = 286x + 19407',linewidth=2.0)
plt.plot(datapoints,Gas_variance, color='r',label = 'Variance | y = 456x+19407',linewidth=2.0)
plt.ticklabel_format(style='plain')
leg = plt.legend(prop={'size': 15},loc= 2)
# fig.suptitle('Mean  And Vairiance Computational Cost Scalability',fontsize=12, )
plt.xlabel('Number of datapoints for training',fontsize=17)
plt.ylabel('Gas Consumtion In GWei',fontsize=17)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.savefig('mean-variance-cost.pdf',bbox_inches ='tight')

# %%
y1 = Gas_mean[10]
y2 = Gas_mean[20]
x1 = datapoints[10]
x2 = datapoints[20]
m =(y2-y1)/(x2-x1)
print(m)

c = Gas_mean[20] - m*datapoints[20]
print(c)
# Out:
# 286.225
# 19407.5

# %%
y1 = Gas_variance[10]
y2 = Gas_variance[20]
x1 = datapoints[10]
x2 = datapoints[20]
m =(y2-y1)/(x2-x1)
print(m)

c = Gas_variance[20] - m*datapoints[20]
print(c)
# Out:
# 455.225
# 21373.5

# %%
feature=np.arange(64)
gas_consumed =np.array([988723,1046282,1114916,1352800,1512500,1677500,1842500,2007500,2180000,2350000,2522500,2700000,2877500,3057500,3240000,3422750,3607500,3795000,3985000,4177500,4370250,4567500,4766000,4966000,5167500,5372500,5578250,5786250,5975000,6209050,6422500,6640000,6857500,7077500,7300000,7525000,7750000,7980000,8210000,8442500,8677500,8915000,9150000,9395000,9645000,9882500,10125000,10377750,10627500,10755000,11012250,11270000,11527500,11790000,12053000,12318200,12585350,12735350,13002500,13252500,13550000,13827500,14107650,14310250])

y1 = gas_consumed[10]
y2 = gas_consumed[40]

x1 = feature[10]
x2 = feature[40]
m =(y2-y1)/(x2-x1)
print(m)

c = gas_consumed[10] - m*feature[10]
print(c)
# Out:
# 205166.66666666666
# 470833.3333333335

# %%
fig = plt.figure(figsize=(10, 10))
plt.plot(feature,gas_consumed, color='b',label ='y = 205166x + 470833',linewidth=2.0)
plt.ticklabel_format(style='plain')
leg = plt.legend(prop={'size': 16},loc= 2)
# fig.suptitle('Mean  And Vairiance Computational Cost Scalability',fontsize=12, )
plt.xlabel('Number of features',fontsize=17)
plt.ylabel('Gas Consumtion in GWei',fontsize=17)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.savefig('feature-cost.pdf',bbox_inches ='tight')

# %%
classes=["2-Class","3-Class","4-Class","5-Class","6-Class","7-Class","8-Class","9-Class","10-Class"]
contract = np.array([0.0001126,0.00091,0.00174,0.002694,0.003547,0.004622,0.005449,0.006413,0.007377])
probability = np.array([0.00103866,0.00138679,0.00174932,0.00211925,0.00243398,0.00283581,0.00317814,0.00353556,0.00389298])

# y1 = contract[3]
# y2 = gas_consumed[7]
# x1 = feature[10]
# x2 = feature[40]
# m1 =(y2-y1)/(x2-x1)
# print(m1)

# c1 = Gas_mean[20] - m1*datapoints[20]
# print(c1)


# y1 = gas_consumed[10]
# y2 = gas_consumed[40]
# x1 = feature[10]
# x2 = feature[40]
# m2 =(y2-y1)/(x2-x1)
# print(m2)

# c2 = Gas_mean[20] - m2*datapoints[20]
# print(c1)

y2 = probability[4]
y1 = probability[0]
x2 = 6
x1 = 2
m = (y2-y1)/(x2-x1)
c = y2 -m*x2 
print(m,c)
fig = plt.figure(figsize=(10, 10))
# plt.plot(classes,contract, color='b',label ='Contract Deployment',linewidth=2.0)
plt.plot(classes,probability, color='r',label ='y = 0.000348x + .000341',linewidth=2.0)
# plt.ticklabel_format(style='plain')
leg = plt.legend(prop={'size': 16},loc= 2)
# fig.suptitle('Mean  And Vairiance Computational Cost Scalability',fontsize=12, )
plt.xlabel('Number of Classes',fontsize=17)
plt.ylabel('Prediction Function Cost in Ethers',fontsize=17)
plt.xticks(fontsize=16,rotation =90)
plt.yticks(fontsize=16)
plt.savefig('Class-cost.pdf',bbox_inches ='tight')
# Out:
# 0.00034883 0.00034100000000000016

# %%
,
# Out:
# ''

# %%
datapoints=[100,200,300,400,500,600,700,800,900,1000,2000,3000,4000]
mean_time = [13.71600604057312,13.826740741729736,17.586567163467407,17.737958192825317,6.183846473693848,6.31611967086792,6.271266937255859,6.4160380363464355,23.426634550094604,23.5510311126709,14.857524156570435,15.003347158432007,5.427577495574951]
variance_time= [22.433719158172607,39.22536015510559,25.149372816085815,4.8344221115112305,14.692938804626465,23.157147884368896,11.734829664230347,38.79718065261841,4.424042224884033,34.37258982658386,5.447770357131958,14.60145902633667,15.508707523345947]
print(len(mean_time))
print(len(variance_time))
fig = plt.figure(figsize=(10, 10))
plt.plot(datapoints,mean_time,marker='o', color='b',label ='Mean',linewidth=2.0)
plt.plot(datapoints,variance_time,marker='o', color='r',label = 'Variance',linewidth=2.0)
plt.ticklabel_format(style='plain')
leg = plt.legend()
fig.suptitle('Mean  And Vairiance Compuational Time Scalability',fontsize=12)
plt.xlabel('Number of datapoints for training',fontsize=12)
plt.ylabel('Duration of copmputations in seconds',fontsize=12)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# plt.set(xlabel='Data points', ylabel='Gas Use',
#        title='Gas use versus Mean & variance Calculation')
# plt.show()
# plt.savefig('time.pdf')
# Out:
# 13
# 13
# (array([ 0.,  5., 10., 15., 20., 25., 30., 35., 40., 45.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
#classification gas use

datapoints=['Class=2', 'Class=3', 'Class=4','Class=5','Class=6','Class=7']
gasuse_4 =[466173,541419,687575,825265,924951,1102495]
gasuse_5 =[415491,518583,645813,827648,951645,1133633] 
fig = plt.figure(figsize=(10, 10))
plt.plot(datapoints,gasuse_4, color='r',marker ='o',linewidth=3.0,label =' 4-Feature')
plt.plot(datapoints,gasuse_5, color='b',marker='o',linewidth=3.0,label =' 5-Feature')

plt.ticklabel_format(style='plain', axis='y')
leg = plt.legend(prop={'size': 14},loc= 2)

plt.xlabel('Complete Prediction Gas Use of Different Classes',fontsize=14,fontweight = 'bold')
plt.ylabel('Gas Use in GWEI',fontsize=14,fontweight ='bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# plt.set(xlabel='Data points', ylabel='Gas Use',
#        title='Gas use versus Mean & variance Calculation')
# plt.show()
plt.savefig('feature-cost.pdf')

# %%
# x = np.arange(500).tolist()
# z = int(np.mean(x))
# # print(z)
# print(x,',',x,',',x,',',x,',',z,',',z,',',z,',',z,',',len(x))

# %%
# importing libraries
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
 
# defining surface and axes
x = np.outer(np.linspace(-2, 2, 10), np.ones(10))
y = x.copy().T
z = np.cos(x ** 2 + y ** 3)
 
fig = plt.figure()
 
# syntax for 3-D plotting
ax = plt.axes(projection ='3d')
 
# syntax for plotting
ax.plot_surface(x, y, z, cmap ='viridis', edgecolor ='green')
ax.set_title('Surface plot geeks for geeks')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from mpl_toolkits.mplot3d import Axes3D

## Matplotlib Sample Code using 2D arrays via meshgrid
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X ** 2 + Y ** 2)
Z = np.sin(R)
fig = plt.figure()
ax = Axes3D(fig)
surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
ax.set_zlim(-1.01, 1.01)

ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

fig.colorbar(surf, shrink=0.5, aspect=5)
plt.title('Original Code')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from mpl_toolkits.mplot3d import Axes3D

## Matplotlib Sample Code using 2D arrays via meshgrid
Y = np.arange(1,3000 , 100)
X = np.arange(1, 21, 1 )
X, Y = np.meshgrid(X, Y)

df = pd.read_csv('NB-March 2022.csv',index_col=0,)
Z = df.to_numpy()
# print(Z)
# print(df.head())
# Z = Z.T
print(X.shape)
print(Y.shape)
print(Z.shape)

fig = plt.figure()
ax = Axes3D(fig)
surf = ax.plot_surface(X, Y, Z,  cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
# ax.set_zlim(-1.01, 1.01)

ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-5e4357c7f610> in <module>
#      10 X, Y = np.meshgrid(X, Y)
#      11
# ---> 12 df = pd.read_csv('NB-March 2022.csv',index_col=0,)
#      13 Z = df.to_numpy()
#      14 # print(Z)
#
# c:\users\syed\appdata\local\programs\python\python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from mpl_toolkits.mplot3d import Axes3D

## Matplotlib Sample Code using 2D arrays via meshgrid
Y = np.arange(1,3000 , 100)
X = np.arange(1, 21, 1 )
X, Y = np.meshgrid(X, Y)

df = pd.read_csv('NB-VARIANCE.csv',index_col=0,)
ZZ = df.to_numpy()
# print(Z)
# print(df.head())
# Z = Z.T
# print(X.shape)
# print(Y.shape)
# print(ZZ.shape)

fig = plt.figure(figsize=(10,10))
ax = Axes3D(fig)
# surf = ax.plot_surface(X, Y, Z,  cmap=cm.coolwarm,
#                        linewidth=0, antialiased=False)
surf = ax.plot_surface(X, Y, ZZ,  cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
# ax.set_zlim(-1.01, 1.01)

ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

fig.colorbar(surf, shrink=0.5, aspect=5, pad =0.14)
ax.set_xticks(X[0])
ax.zaxis.set_tick_params(labelsize=14)
# plt.title(" Cost of Variance with respect to number of features and samples")
plt.xlabel(" Number of features",fontsize=14, labelpad =5)
plt.ylabel(" Number of samples",fontsize=14, labelpad = 7)
plt.xticks(np.arange(1,21,2), np.arange(1,21,2),fontsize=14)
plt.yticks(fontsize=14)
ax.set_zlabel('Transaction Cost In Ethers',fontsize=14,labelpad= 7)
plt.savefig("3d-variance-cost.pdf", bbox_inches='tight')
plt.show()

# %%
# x = np.arange(500).tolist()
# print(x,',',x,',',x,',',x,',',len(x))

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from mpl_toolkits.mplot3d import Axes3D

## Matplotlib Sample Code using 2D arrays via meshgrid
Y = np.arange(1,3000 , 100)
X = np.arange(1, 21, 1 )
X, Y = np.meshgrid(X, Y)

df = pd.read_csv('NB-MEAN.csv',index_col=0,)
ZZ = df.to_numpy()
# print(Z)
# print(df.head())
# Z = Z.T
# print(X.shape)
# print(Y.shape)
# print(ZZ.shape)

fig = plt.figure(figsize=(10,10))
ax = Axes3D(fig)
# surf = ax.plot_surface(X, Y, Z,  cmap=cm.coolwarm,
#                        linewidth=0, antialiased=False)
surf = ax.plot_surface(X, Y, ZZ,  cmap=cm.PRGn,
                       linewidth=0, antialiased=False)
# ax.set_zlim(-1.01, 1.01)

ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

fig.colorbar(surf, shrink=0.5, aspect=5, pad =0.1)
ax.tick_params(labelsize=14) 
ax.set_xticks(X[0])
ax.zaxis.set_tick_params(labelsize=14)
plt.xticks(np.arange(1,21,2), np.arange(1,21,2),fontsize=14)
plt.yticks(fontsize=14)
# plt.title(" Cost of Variance with respect to number of features and samples")
plt.xlabel(" Number of features",fontsize=14,labelpad = 5)
plt.ylabel(" Number of samples",fontsize=14, labelpad = 7)
ax.set_zlabel('Transaction Cost In Ethers',fontsize=14 , labelpad = 7)
plt.savefig("3d-mean-cost.pdf", bbox_inches='tight')
plt.show()
